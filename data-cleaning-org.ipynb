# %%
import mysql.connector as msql
from mysql.connector import Error
import pandas as pd
from sqlalchemy import create_engine
import re

# %%
try:
    conn = msql.connect(host='3.110.5.152',port='3306', user='dbuser',  
                        password='fk5%Ht3=OSwx',auth_plugin='mysql_native_password')
    if conn.is_connected():
        cursor = conn.cursor()
        print("Database is created")
except Error as e:
        print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %%
sql_query = "select * from mktg_source.dec2021;"
df = pd.read_sql(sql_query,conn)

# %%
conn.close()

# %%
df
# Out:
#                              Name                             Email  \
# 0                     Mallikarjun  mallikarjunrammanthale@gmail.com
# 1                      E Srinivas          srinu777sardar@gmail.com
# 2                  Dharani Thouda           dharanithouda@gmail.com
# 3      Mohammad Zeeshan Ali Ahmed       zeeshanaliahmed95@gmail.com
# 4                      N Sukendar          sukkusukendarr@gmail.com
# ...                           ...                               ...
# 46281        Chennuru Prudhvi Raj     prudhvirajchennuru5@gmail.com
# 46282          Ayaz Baig mohammed             ayazbaigmd3@gmail.com
# 46283         Anumala setty Anjan      anjan.anumalasetty@gmail.com
# 46284       Sai Nikhitendra Kunar          nikithendra123@gmail.com
# 46285        Tunuguntla Chandhini     tunuguntlachandhini@gmail.com
#
#       Mobile Number Qualification Year of Passing Gender Stream  \
# 0      919591977617    B.Tech/B.E          2020.0   None   None
# 1      916304918491    B.Tech/B.E          2019.0   None   None
# 2      917989358531    B.Tech/B.E          2020.0   None   None
# 3      919493894710    B.Tech/B.E          2021.0   None   None
# 4      919885463335    B.Tech/B.E          2018.0   None   None
# ...             ...           ...             ...    ...    ...
# 46281  919550939463    B.Tech/B.E          2018.0   None   None
# 46282  917981813827    B.Tech/B.E          2021.0   None   None
# 46283  918897224145    B.Tech/B.E          2018.0   None   None
# 46284  918374093625    B.Tech/B.E          2019.0   None   None
# 46285  917337546891    B.Tech/B.E          2020.0   None   None
#
#                  City State  Role Total Exp            Database Date  \
# 0           Hyderabad  None  None      None  2021/12/01 00:00:00.000
# 1           Hyderabad  None  None      None  2021/12/01 00:00:00.000
# 2           Hyderabad  None  None      None  2021/12/01 00:00:00.000
# 3           Hyderabad  None  None      None  2021/12/01 00:00:00.000
# 4           Hyderabad  None  None      None  2021/12/01 00:00:00.000
# ...               ...   ...   ...       ...                      ...
# 46281  Vishakhapatnam  None  None      None  2021/12/23 00:00:00.000
# 46282          Guntur  None  None      None  2021/12/23 00:00:00.000
# 46283      Vijayawada  None  None      None  2021/12/23 00:00:00.000
# 46284        Anantpur  None  None      None  2021/12/23 00:00:00.000
# 46285      Vijayawada  None  None      None  2021/12/23 00:00:00.000
#
#                Source Source Details Source Code Funnel  Daily Datewise Data
# 0      Naukri Crystal           None        None   None  30th Nov to 1st Dec
# 1      Naukri Crystal           None        None   None                 None
# 2      Naukri Crystal           None        None   None                 None
# 3      Naukri Crystal           None        None   None                 None
# 4      Naukri Crystal           None        None   None                 None
# ...               ...            ...         ...    ...                  ...
# 46281  Naukri Crystal           None        None   None                 None
# 46282  Naukri Crystal           None        None   None                 None
# 46283  Naukri Crystal           None        None   None                 None
# 46284  Naukri Crystal           None        None   None                 None
# 46285  Naukri Crystal           None        None   None                 None
#
# [46286 rows x 17 columns]

# %%
df.isna().sum()
# Out:
# Name                     125
# Email                      0
# Mobile Number            174
# Qualification              0
# Year of Passing            0
# Gender                 46286
# Stream                 46286
# City                       1
# State                  46286
# Role                   18517
# Total Exp              18517
# Database Date              0
# Source                     0
# Source Details         45846
# Source Code            46286
# Funnel                 46286
# Daily Datewise Data    46268
# dtype: int64

# %%
def remove_plus(phone):
    if phone is None:
        return None
    phone=phone.replace(" ","")
    
    if phone is not None:
        return phone.replace('+', '')
df['Mobile Number'] = df['Mobile Number'].apply(remove_plus)

# %%
df.isna().sum()
# Out:
# Daily Datewise Data    101869
# Name                        5
# Email                       5
# Mobile Number               0
# Qualification              20
# Gender                  43788
# Stream                  43449
# Year of Passing            17
# college                 43455
# % in IT                101904
# City                     5007
# State                   99945
# Role                    97897
# Total Exp                  20
# Date                        0
# Source                      0
# dtype: int64

# %%
df
# Out:
#        Daily Datewise Data                       Name  \
# 0                  2nd Sep                AKASH KUMAR
# 1                     None                  Kuchipudi
# 2                     None             vignesh mehala
# 3                     None               Saritha sari
# 4                     None        Prashant Srivastava
# ...                    ...                        ...
# 101899                None                 Shyamala M
# 101900                None                       Jery
# 101901                None  Hadpad Basavraj Siddharam
# 101902                None      Sandesh Sahebrao Kale
# 101903      SCH 12-12-2022               Muthukumar P
#
#                                      Email Mobile Number Qualification  \
# 0                      ak9149031@gmail.com  917388784014    B.Tech/B.E
# 1                   18a81a05e4@sves.org.in  919381533159    B.Tech/B.E
# 2                vigneshmehala14@gmail.com  919344057826    B.Tech/B.E
# 3              sarithanenavath16@gmail.com  919603274917    B.Tech/B.E
# 4       prashantsrivastava302000@gmail.com  916387965775    B.Tech/B.E
# ...                                    ...           ...           ...
# 101899               shyamalam07@gmail.com  919686994110    B.Tech/B.E
# 101900              hariharanc81@gmail.com  919840224965    B.Tech/B.E
# 101901             rajhadpad1999@gmail.com  918446988486    B.Tech/B.E
# 101902           sandeshkale2597@gmail.com  918208192012    B.Tech/B.E
# 101903            muthukumars883@gmail.com  919659691627    B.Tech/B.E
#
#         Gender                         Stream Year of Passing  \
# 0         Male                    IT-Software            2022
# 1       Female                      Computers            2022
# 2         Male                    IT-Software            2022
# 3       Female                      Computers            2022
# 4         Male  Electronics/Telecommunication            2022
# ...        ...                            ...             ...
# 101899  Female                      Computers            2020
# 101900    Male                    IT-Software            2021
# 101901    Male                     Mechanical            2020
# 101902    Male                     Mechanical            2021
# 101903    Male                    IT-Software            2020
#
#                                                   college % in IT  \
# 0                                           U . P . BOARD    None
# 1                                                  Vasavi    None
# 2                                         anna university    None
# 3            brilliant group of institutions, ranga reddy    None
# 4                  punjab technical university, jalandhar    None
# ...                                                   ...     ...
# 101899        South east asian engineering and technology    None
# 101900                dr mgr engineering college, chennai    None
# 101901  Dy patil college of engineering and innovation...    None
# 101902  RMD SINHGAD TECHNICAL INSTITUTES CAMPUS WARJE ...    None
# 101903         muthayammal engineering college, rasipuram    None
#
#                  City State  Role     Total Exp           Date Source
# 0            Gurugram  None  None  0 Yr 0 Month   2nd Sep 2022  Shine
# 1       West Godavari  None  None  0 Yr 0 Month   2nd Sep 2022  Shine
# 2             Chennai  None  None  0 Yr 0 Month   2nd Sep 2022  Shine
# 3           Hyderabad  None  None  0 Yr 0 Month   2nd Sep 2022  Shine
# 4               Noida  None  None  0 Yr 0 Month   2nd Sep 2022  Shine
# ...               ...   ...   ...           ...            ...    ...
# 101899       Silvassa  None  None  0 Yr 0 Month  28th Sep 2022  Shine
# 101900       Anantpur  None  None  0 Yr 0 Month  28th Sep 2022  Shine
# 101901           Pune  None  None  0 Yr 0 Month  28th Sep 2022  Shine
# 101902           Pune  None  None  0 Yr 0 Month  28th Sep 2022  Shine
# 101903          Erode  None  None  0 Yr 0 Month  28th Sep 2022  Shine
#
# [101904 rows x 16 columns]

# %%
IndMob_Ptrn="^(\+91[\-\s]?)?[0]?(91)?[6-9]\d{9}$"
def gt_len(phone):
    if phone is None:
        return None
    phone_list = phone.split(',')
    for number in phone_list:
        if bool(re.match(IndMob_Ptrn, number)):
            return '91'+number[-10:]
    return None        
df['Mobile Number'] = df['Mobile Number'].apply(gt_len)

# %%
df.isna().sum()
# Out:
# Daily Datewise Data    101869
# Name                        5
# Email                       5
# Mobile Number            2404
# Qualification              20
# Gender                  43788
# Stream                  43449
# Year of Passing            17
# college                 43455
# % in IT                101904
# City                     5007
# State                   99945
# Role                    97897
# Total Exp                  20
# Date                        0
# Source                      0
# dtype: int64

# %%
engine = create_engine('mysql+pymysql://db_user:fk5%Ht3=OSwx@3.110.5.152:3306/mktg_source')
conn1 = conn.connect()
df.to_sql(name='sep2022', con=engine, if_exists='replace', index=False)
conn.close()
engine.dispose()

# %%
#df.to_sql(name='mktg_database.exam2022', con=engine, if_exists='replace', index=False)

# %%
#engine.dispose()

# %%
#engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/mktg_database)
